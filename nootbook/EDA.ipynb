# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from nootbook.model_train import x_train

# %%
df = pd.read_csv('data/stud.csv')

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#check nun
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ### Observation --> not null value present in dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race_ethnicity               1000 non-null   str
#  2   parental_level_of_education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test_preparation_course      1000 non-null   str
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %% [markdown]
# ### observation ---> in dataset some are string datatype columns are presents

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
num_col = df.select_dtypes(exclude='string').columns
non_num_col = df.select_dtypes(include='string').columns

print(f"Number of numeric Columns: {len(num_col)} \n Numeric columns: {num_col}")
print(f"Number of  non numeric Columns: {len(non_num_col)} \n Non-numeric columns: {non_num_col}")
# Out:
# Number of numeric Columns: 3
#  Numeric columns: Index(['math_score', 'reading_score', 'writing_score'], dtype='str')
# Number of  non numeric Columns: 5
#  Non-numeric columns: Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course'],
#       dtype='str')

# %%
#check outliers
for col in num_col:
    sns.boxplot(df[col])
    plt.show()

# %%
df['Total_Score'] = df['writing_score'] + df['reading_score'] + df['math_score']
df['Average_Score'] = df['Total_Score']/3

# %%
sns.histplot(data=df, x= 'Average_Score',hue='gender',kde=True)
plt.show()
sns.histplot(data=df, x= 'Total_Score',hue='gender',kde=True)
plt.show()

# %% [markdown]
# ### Observation ---> Female score more than male category

# %%
for col in non_num_col:
    print(f"Unique value : \n {col} : {df[col].unique()}")
# Out:
# Unique value :
#  gender : <StringArray>
# ['female', 'male']
# Length: 2, dtype: str
# Unique value :
#  race_ethnicity : <StringArray>
# ['group B', 'group C', 'group A', 'group D', 'group E']
# Length: 5, dtype: str
# Unique value :
#  parental_level_of_education : <StringArray>
# [ 'bachelor's degree',       'some college',    'master's degree',
#  'associate's degree',        'high school',   'some high school']
# Length: 6, dtype: str
# Unique value :
#  lunch : <StringArray>
# ['standard', 'free/reduced']
# Length: 2, dtype: str
# Unique value :
#  test_preparation_course : <StringArray>
# ['none', 'completed']
# Length: 2, dtype: str

# %%
sns.histplot(data=df,x='Total_Score',hue='race_ethnicity',kde=True)
plt.show()
sns.histplot(data=df,x='Average_Score',hue='race_ethnicity',kde=True)
plt.show()

# %%
x = {"m": 5, "p":14}
for k,v in x.items():
    print(f"{k} : {v}")
# Out:
# m : 5
# p : 14

# %%
key, val = max(x.items(), key=lambda kv: kv[1])

# %%
print(key,val)
# Out:
# p 14
